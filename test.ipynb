# %%
from PIL import Image 
import pytesseract 
import sys 
from pdf2image import convert_from_path 
import os 
import cv2
import numpy as np

# %%
pages = convert_from_path('sample.pdf')

# %%
print(pages)
# Out:
# [<PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=1700x2200 at 0x2D19EA56088>]

# %%
pages_in_img = []
for i, page in enumerate(pages):
    filename = "pdfsmaples\page_%s.jpg"%i
    page = page.convert('L')
    pages_in_img.append(np.array(page))
    cv2.imwrite(filename, pages_in_img[-1])

# %%
for img in pages_in_img:
    pass

# %%
ret,thresh_value = cv2.threshold(img,240,255,cv2.THRESH_BINARY_INV)

# %%
cv2.imshow("img", thresh_value)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
ret
# Out:
# 240.0

# %%
cv2.HoughLinesP(thresh_value, )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-0e6aa8eb57fb> in <module>
# ----> 1 cv2.HoughLinesP(thresh_value, )
#
# TypeError: HoughLinesP() missing required argument 'rho' (pos 2)
